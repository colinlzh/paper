# %%
data=["1000,20141111,A","1000,20141111,B","1000,20141112,C","1001,20141111,A","1001,20141112,A"]
l=sc.parallelize(data)

# %%
l=l.map(lambda x:x.split(",")).map(lambda x:(x[0],(x[1],x[2]))).groupByKey().mapValues(list)

# %%
l.first()
# Out:
# ('1000', [('20141111', 'A'), ('20141111', 'B'), ('20141112', 'C')])

# %%
def get_freq(l):
#     get the frequent
    place=l[0]
    myset=l[1]
    d=[]
    for i in place:
        day=i[0]
        freq=myset[day]
        d.append([day,i[1],freq])
    return d
place=l.join(user).mapValues(get_freq).flatMap(lambda x:x[1])

# %%
data=sc.textFile("./part-*")
al=data.map(lambda x:(x.split(" ")[0]," ".join(x.split(" ")[1:])))
al=al.filter(lambda x:x[1].find("null")==-1 and\
        time.localtime(time.mktime(time.strptime(x[1].split(" ")[1]+" "+x[1].split(" ")[2],"%Y-%m-%d %H:%M:%S"))-10800).tm_wday<5)
al.cache()

motif = al.groupByKey()\
            .mapValues(list)\
            .mapValues(sor)\
            .map(lambda x:(x[0],style_conv(location_to_motif(x[1]))))
all_motif=motif.flatMap(lambda x:x[1]).distinct().collect()
broad_motif=sc.broadcast(motifiso(all_motif))
isomotif=motif.flatMapValues(lambda x:x)\
            .mapValues(lambda x:iso(x,broad_motif.value))\
            .groupByKey()\
            .mapValues(list) 
everyone_motif=isomotif.mapValues(count_motif)
motifday = al.groupByKey()\
                .mapValues(list)\
                .mapValues(sor)\
                .mapValues(location_to_motif_anddate)\
                .mapValues(lambda x:day_iso(x,broad_motif.value))\
                .flatMapValues(lambda x:x)
def be_dict(l):
    l=list(l)
    d={}
    for i in l:
        d[i[0]]=i[1]
    return d
motifday.join(everyone_motif).mapValues(lambda x:(x[0][0],x[1][x[0][1]])).groupByKey().mapValues(be_dict).collect()
# Out:
# [('89076974',
#   {'2014-09-16': 3,
#    '2014-09-17': 6,
#    '2014-09-18': 16,
#    '2014-09-19': 5,
#    '2014-09-22': 14,
#    '2014-09-23': 6,
#    '2014-09-24': 1,
#    '2014-09-26': 3,
#    '2014-09-29': 16,
#    '2014-09-30': 14,
#    '2014-10-09': 5,
#    '2014-10-10': 16,
#    '2014-10-13': 16,
#    '2014-10-15': 1,
#    '2014-10-17': 14,
#    '2014-10-20': 16,
#    '2014-10-21': 16,
#    '2014-10-22': 1,
#    '2014-10-23': 14,
#    '2014-10-24': 6,
#    '2014-10-27': 14,
#    '2014-10-28': 16,
#    '2014-10-31': 16,
#    '2014-11-03': 5,
#    '2014-11-04': 6,
#    '2014-11-05': 5,
#    '2014-11-06': 16,
#    '2014-11-07': 2,
#    '2014-11-10': 1,
#    '2014-11-11': 1,
#    '2014-11-12': 1,
#    '2014-11-13': 2,
#    '2014-11-14': 16,
#    '2014-11-17': 14,
#    '2014-11-18': 14,
#    '2014-11-20': 3,
#    '2014-11-24': 14,
#    '2014-11-25': 1,
#    '2014-11-26': 1,
#    '2014-11-27': 16,
#    '2014-11-28': 14,
#    '2014-12-03': 14,
#    '2014-12-04': 6,
#    '2014-12-05': 14,
#    '2014-12-08': 16,
#    '2014-12-09': 2,
#    '2014-12-11': 1,
#    '2014-12-12': 14,
#    '2014-12-15': 3,
#    '2014-12-16': 3,
#    '2014-12-17': 1,
#    '2014-12-18': 1,
#    '2014-12-19': 6,
#    '2014-12-22': 2,
#    '2014-12-23': 3,
#    '2014-12-24': 16,
#    '2014-12-25': 16,
#    '2014-12-26': 16,
#    '2014-12-29': 2,
#    '2014-12-30': 3,
#    '2014-12-31': 3,
#    '2015-01-05': 14,
#    '2015-01-06': 3,
#    '2015-01-07': 16,
#    '2015-01-08': 14,
#    '2015-01-09': 5,
#    '2015-01-12': 2}),
#  ('19050472',
#   {'2014-09-15': 35,
#    '2014-09-16': 35,
#    '2014-09-17': 19,
#    '2014-09-18': 19,
#    '2014-09-19': 19,
#    '2014-09-22': 35,
#    '2014-09-23': 35,
#    '2014-09-24': 19,
#    '2014-09-25': 19,
#    '2014-09-26': 19,
#    '2014-09-29': 35,
#    '2014-09-30': 35,
#    '2014-10-02': 35,
#    '2014-10-06': 35,
#    '2014-10-07': 19,
#    '2014-10-08': 7,
#    '2014-10-10': 19,
#    '2014-10-13': 35,
#    '2014-10-15': 35,
#    '2014-10-16': 35,
#    '2014-10-17': 19,
#    '2014-10-20': 19,
#    '2014-10-21': 19,
#    '2014-10-23': 7,
#    '2014-10-24': 35,
#    '2014-10-27': 19,
#    '2014-10-28': 19,
#    '2014-10-31': 19,
#    '2014-11-03': 35,
#    '2014-11-04': 35,
#    '2014-11-06': 35,
#    '2014-11-07': 19,
#    '2014-11-10': 7,
#    '2014-11-11': 4,
#    '2014-11-12': 35,
#    '2014-11-13': 35,
#    '2014-11-14': 35,
#    '2014-11-17': 19,
#    '2014-11-18': 35,
#    '2014-11-19': 4,
#    '2014-11-20': 35,
#    '2014-11-21': 35,
#    '2014-11-24': 35,
#    '2014-11-25': 35,
#    '2014-11-26': 7,
#    '2014-11-27': 35,
#    '2014-12-01': 35,
#    '2014-12-02': 19,
#    '2014-12-04': 7,
#    '2014-12-05': 35,
#    '2014-12-08': 19,
#    '2014-12-10': 2,
#    '2014-12-11': 35,
#    '2014-12-15': 7,
#    '2014-12-17': 4,
#    '2014-12-18': 1,
#    '2014-12-19': 4,
#    '2014-12-22': 35,
#    '2014-12-23': 2,
#    '2014-12-24': 1,
#    '2014-12-25': 35,
#    '2014-12-26': 35,
#    '2014-12-29': 7,
#    '2014-12-30': 35,
#    '2014-12-31': 19,
#    '2015-01-06': 35,
#    '2015-01-07': 35,
#    '2015-01-08': 35,
#    '2015-01-16': 35}),
#  ('98102248',
#   {'2014-09-15': 15,
#    '2014-09-16': 15,
#    '2014-09-17': 2,
#    '2014-09-18': 1,
#    '2014-09-19': 8,
#    '2014-09-22': 17,
#    '2014-09-23': 7,
#    '2014-09-24': 1,
#    '2014-09-25': 7,
#    '2014-09-26': 8,
#    '2014-09-29': 15,
#    '2014-10-02': 17,
#    '2014-10-03': 19,
#    '2014-10-06': 19,
#    '2014-10-07': 7,
#    '2014-10-08': 17,
#    '2014-10-09': 15,
#    '2014-10-10': 2,
#    '2014-10-13': 17,
#    '2014-10-14': 7,
#    '2014-10-15': 1,
#    '2014-10-16': 17,
#    '2014-10-17': 17,
#    '2014-10-20': 3,
#    '2014-10-21': 19,
#    '2014-10-22': 19,
#    '2014-10-23': 7,
#    '2014-10-24': 19,
#    '2014-10-29': 17,
#    '2014-10-30': 8,
#    '2014-11-03': 19,
#    '2014-11-04': 1,
#    '2014-11-05': 15,
#    '2014-11-06': 2,
#    '2014-11-07': 3,
#    '2014-11-10': 15,
#    '2014-11-11': 8,
#    '2014-11-12': 17,
#    '2014-11-13': 15,
#    '2014-11-14': 19,
#    '2014-11-17': 19,
#    '2014-11-18': 8,
#    '2014-11-19': 17,
#    '2014-11-20': 15,
#    '2014-11-21': 19,
#    '2014-11-24': 2,
#    '2014-11-25': 7,
#    '2014-11-26': 15,
#    '2014-11-27': 8,
#    '2014-11-28': 8,
#    '2014-12-01': 15,
#    '2014-12-02': 17,
#    '2014-12-03': 7,
#    '2014-12-04': 17,
#    '2014-12-05': 19,
#    '2014-12-09': 17,
#    '2014-12-10': 15,
#    '2014-12-11': 17,
#    '2014-12-12': 15,
#    '2014-12-15': 17,
#    '2014-12-16': 19,
#    '2014-12-17': 15,
#    '2014-12-18': 19,
#    '2014-12-19': 17,
#    '2014-12-22': 19,
#    '2014-12-23': 1,
#    '2014-12-24': 19,
#    '2014-12-25': 17,
#    '2014-12-26': 8,
#    '2014-12-29': 15,
#    '2014-12-30': 3,
#    '2014-12-31': 19,
#    '2015-01-06': 15,
#    '2015-01-07': 17,
#    '2015-01-08': 19,
#    '2015-01-09': 19,
#    '2015-01-13': 19,
#    '2015-01-15': 19,
#    '2015-01-16': 1}),
#  ('94194436',
#   {'2014-12-15': 2,
#    '2014-12-16': 1,
#    '2014-12-19': 2,
#    '2014-12-22': 9,
#    '2014-12-23': 1,
#    '2014-12-24': 1,
#    '2014-12-25': 9,
#    '2014-12-29': 9,
#    '2014-12-30': 9,
#    '2015-01-09': 9,
#    '2015-01-12': 9,
#    '2015-01-13': 9,
#    '2015-01-14': 9,
#    '2015-01-15': 9,
#    '2015-01-16': 1}),
#  ('99054362',
#   {'2014-09-16': 28,
#    '2014-09-17': 6,
#    '2014-09-18': 19,
#    '2014-09-23': 2,
#    '2014-09-26': 28,
#    '2014-09-29': 8,
#    '2014-09-30': 28,
#    '2014-10-06': 28,
#    '2014-10-07': 28,
#    '2014-10-08': 19,
#    '2014-10-09': 6,
#    '2014-10-10': 6,
#    '2014-10-13': 19,
#    '2014-10-14': 3,
#    '2014-10-15': 28,
#    '2014-10-16': 8,
#    '2014-10-17': 8,
#    '2014-10-20': 2,
#    '2014-10-21': 2,
#    '2014-10-22': 8,
#    '2014-10-23': 1,
#    '2014-10-24': 2,
#    '2014-10-27': 1,
#    '2014-10-28': 28,
#    '2014-10-29': 19,
#    '2014-10-30': 1,
#    '2014-10-31': 3,
#    '2014-11-03': 28,
#    '2014-11-04': 19,
#    '2014-11-05': 1,
#    '2014-11-06': 8,
#    '2014-11-07': 28,
#    '2014-11-10': 3,
#    '2014-11-11': 28,
#    '2014-11-12': 19,
#    '2014-11-13': 28,
#    '2014-11-14': 2,
#    '2014-11-17': 19,
#    '2014-11-18': 28,
#    '2014-11-19': 19,
#    '2014-11-20': 19,
#    '2014-11-21': 2,
#    '2014-11-24': 28,
#    '2014-11-25': 6,
#    '2014-11-26': 19,
#    '2014-11-27': 2,
#    '2014-11-28': 8,
#    '2014-12-01': 19,
#    '2014-12-02': 19,
#    '2014-12-03': 6,
#    '2014-12-04': 28,
#    '2014-12-05': 3,
#    '2014-12-08': 3,
#    '2014-12-09': 28,
#    '2014-12-10': 19,
#    '2014-12-11': 3,
#    '2014-12-12': 28,
#    '2014-12-15': 28,
#    '2014-12-16': 28,
#    '2014-12-17': 28,
#    '2014-12-18': 28,
#    '2014-12-19': 2,
#    '2014-12-22': 28,
#    '2014-12-23': 19,
#    '2014-12-24': 8,
#    '2014-12-25': 28,
#    '2014-12-26': 6,
#    '2014-12-29': 19,
#    '2014-12-31': 19,
#    '2015-01-01': 28,
#    '2015-01-02': 28,
#    '2015-01-05': 28,
#    '2015-01-06': 28,
#    '2015-01-07': 19,
#    '2015-01-08': 28,
#    '2015-01-12': 19,
#    '2015-01-13': 19,
#    '2015-01-15': 8,
#    '2015-01-16': 28}),
#  ('99122311',
#   {'2014-09-15': 49,
#    '2014-09-16': 49,
#    '2014-09-17': 49,
#    '2014-09-18': 49,
#    '2014-09-19': 49,
#    '2014-09-22': 49,
#    '2014-09-23': 49,
#    '2014-09-24': 49,
#    '2014-09-25': 11,
#    '2014-09-29': 49,
#    '2014-10-06': 49,
#    '2014-10-07': 49,
#    '2014-10-08': 11,
#    '2014-10-09': 4,
#    '2014-10-13': 49,
#    '2014-10-15': 49,
#    '2014-10-16': 11,
#    '2014-10-17': 49,
#    '2014-10-20': 49,
#    '2014-10-21': 49,
#    '2014-10-22': 9,
#    '2014-10-23': 49,
#    '2014-10-24': 49,
#    '2014-10-27': 49,
#    '2014-10-29': 49,
#    '2014-10-30': 49,
#    '2014-10-31': 49,
#    '2014-11-03': 49,
#    '2014-11-04': 49,
#    '2014-11-05': 49,
#    '2014-11-10': 4,
#    '2014-11-11': 49,
#    '2014-11-12': 49,
#    '2014-11-13': 49,
#    '2014-11-14': 49,
#    '2014-11-17': 49,
#    '2014-11-18': 49,
#    '2014-11-19': 11,
#    '2014-11-20': 49,
#    '2014-11-21': 9,
#    '2014-11-24': 9,
#    '2014-11-25': 4,
#    '2014-11-26': 9,
#    '2014-11-27': 49,
#    '2014-11-28': 49,
#    '2014-12-01': 9,
#    '2014-12-02': 49,
#    '2014-12-04': 49,
#    '2014-12-05': 49,
#    '2014-12-08': 11,
#    '2014-12-09': 49,
#    '2014-12-10': 9,
#    '2014-12-11': 49,
#    '2014-12-12': 11,
#    '2014-12-15': 11,
#    '2014-12-16': 4,
#    '2014-12-17': 49,
#    '2014-12-22': 49,
#    '2014-12-23': 49,
#    '2014-12-24': 49,
#    '2014-12-25': 49,
#    '2014-12-26': 11,
#    '2014-12-29': 49,
#    '2014-12-30': 11,
#    '2014-12-31': 9,
#    '2015-01-05': 11,
#    '2015-01-06': 49,
#    '2015-01-08': 9,
#    '2015-01-09': 49,
#    '2015-01-12': 49,
#    '2015-01-13': 11,
#    '2015-01-14': 9,
#    '2015-01-16': 49}),
#  ('43057656',
#   {'2014-09-16': 38,
#    '2014-09-23': 38,
#    '2014-09-26': 38,
#    '2014-09-30': 38,
#    '2014-10-09': 38,
#    '2014-10-14': 38,
#    '2014-10-16': 38,
#    '2014-10-20': 38,
#    '2014-10-21': 38,
#    '2014-10-22': 38,
#    '2014-10-23': 38,
#    '2014-10-28': 38,
#    '2014-10-30': 38,
#    '2014-11-04': 38,
#    '2014-11-06': 38,
#    '2014-11-07': 38,
#    '2014-11-10': 38,
#    '2014-11-11': 38,
#    '2014-11-13': 38,
#    '2014-11-14': 38,
#    '2014-11-17': 38,
#    '2014-11-18': 38,
#    '2014-11-20': 38,
#    '2014-11-25': 38,
#    '2014-11-27': 38,
#    '2014-12-02': 38,
#    '2014-12-04': 38,
#    '2014-12-09': 3,
#    '2014-12-11': 38,
#    '2014-12-16': 38,
#    '2014-12-17': 3,
#    '2014-12-18': 38,
#    '2014-12-23': 38,
#    '2014-12-24': 38,
#    '2014-12-25': 38,
#    '2014-12-26': 38,
#    '2014-12-30': 38,
#    '2015-01-06': 3,
#    '2015-01-08': 38,
#    '2015-01-12': 38,
#    '2015-01-14': 38,
#    '2015-01-16': 1})]

# %%
user=motifday.join(everyone_motif).mapValues(lambda x:(x[0][0],x[1][x[0][1]])).groupByKey().mapValues(be_dict)

# %%
place.first()
# Out:
# ['20141111', 'A', 1]

# %%
place.map(lambda x:((x[0],x[1]),x[2])).groupByKey().mapValues(list)

# %%
# -*- coding:utf-8 -*- ＃
import sys
import time
import networkx as nx
from operator import add
def sor(l):
    l=sorted(l,key=lambda x:x.split(" ")[1]+x.split(" ")[2]+x.split(" ")[0])
    return l
def location_to_motif(locations):
    dateFlag = ''
    motifList = []
    for i in range(0,len(locations)):
        t=locations[i].split(" ")
        _date = t[1]
        tm = t[2]
        station = t[0]
        if dateFlag=='' or \
        time.mktime(time.strptime(_date+" "+tm,"%Y-%m-%d %H:%M:%S"))-time.mktime(time.strptime(dateFlag,"%Y-%m-%d"))>=97200 or\
                (tm>"03 " and timeFlag<"03"):#if another day, initialize
            dateFlag = _date
            timeFlag = tm
            motifList.append({})
            nodeDict = {}
        if station not in nodeDict.keys():#map station name to node num
            nodeDict[station] = len(nodeDict)
        if nodeDict[station] not in motifList[-1].keys():#add the appeared node to today's motif graph
            motifList[-1][nodeDict[station]] = []
        if (i+1)<len(locations):
            ndate=locations[i+1].split(' ')[1]
            ntime=locations[i+1].split(' ')[2]
            t=time.mktime(time.strptime(_date,"%Y-%m-%d"))
            tt=time.mktime(time.strptime(ndate+" "+ntime,"%Y-%m-%d %H:%M:%S"))
            if tt-t<97200 and tm>"03":#yet is today's
                n_station = locations[i+1].split(' ')[0]
                if not n_station==station:
                    if n_station not in nodeDict.keys():
                        nodeDict[n_station] = len(nodeDict)
                    if not motifList[-1][nodeDict[station]].count(nodeDict[n_station])>0:
                        motifList[-1][nodeDict[station]].append(nodeDict[n_station])

    return motifList
def location_to_motif_anddate(locations):
    dateFlag = ''
    motifList = []
    for i in range(0,len(locations)):
        t=locations[i].split(" ")
        _date = t[1]
        _time = t[2]
        station = t[0]
        if dateFlag=='' or \
         time.mktime(time.strptime(_date+" "+_time,"%Y-%m-%d %H:%M:%S"))-time.mktime(time.strptime(dateFlag,"%Y-%m-%d"))>=97200 or\
                (_time>"03 " and timeFlag<"03"):
            dateFlag = _date #如果不进行这一步的话，说明理论上还要划归到昨天，因此后续轨迹全要划到昨天MOTIF
            shit={}
            timeFlag = _time
            shit[_date]={}
            motifList.append(shit)
            nodeDict = {}
        if station not in nodeDict.keys():#map station name to node num
            nodeDict[station] = len(nodeDict)
        if nodeDict[station] not in shit[dateFlag].keys():#add the appeared node to today's motif graph
            shit[dateFlag][nodeDict[station]] = []
        if (i+1)<len(locations):
            ndate=locations[i+1].split(' ')[1]
            ntime=locations[i+1].split(' ')[2]
            t=time.mktime(time.strptime(_date,"%Y-%m-%d"))
            tt=time.mktime(time.strptime(ndate+" "+ntime,"%Y-%m-%d %H:%M:%S"))
            if (tt-t<97200) and _time>"03":#yet is today's
                n_station = locations[i+1].split(' ')[0]
                if not n_station==station:
                    if n_station not in nodeDict.keys():
                        nodeDict[n_station] = len(nodeDict)
                    if not shit[dateFlag][nodeDict[station]].count(nodeDict[n_station])>0:
                        shit[dateFlag][nodeDict[station]].append(nodeDict[n_station])
    re=[]
    for i in motifList:
        temp=list(i.items())
        re.append([temp[0][0],temp[0][1]])
    return re
def style_conv(list_dict):
    dicts = str(list_dict).strip('[]')
    dicts = dicts.split(', {')
    rsl = []
    for i in range(0, len(dicts)):
        if i ==0:
            rsl.append(dicts[i])
        else:
            rsl.append('{' + dicts[i])
    return rsl
def count_motif(l):
    dic={}
    myset=set(l)
    for i in myset:
        dic[i]=l.count(i)
    return dic
def motifiso(l):
# '''if there is isomorphic motif, set them in one'''
    existed=[]
    flag=False
    for i in l:
        name=i
        lmotif=nx.DiGraph(eval(name))
        if name in existed:
            continue
        for oldname in existed:
            if len(oldname)!=len(name):
                continue
            oldmotif=nx.DiGraph(eval(oldname))
            if nx.is_isomorphic(oldmotif,lmotif):
                flag=True
                break
        if not flag:
            existed.append(i)
        flag=False
    return existed
def day_iso(m,l):
    re=[]
    for i in m:
        b=nx.DiGraph(i[1])
        for a in l:
            if len(a)!=len(str(i[1])):
                continue
            if nx.is_isomorphic(nx.DiGraph(eval(a)),b):
                i[1]=str(a)
                break
        re.append(i)
    return re
def iso(m,l):
    b=nx.DiGraph(eval(m))
    for a in l:
        if len(a)!=len(m):
            continue
        if nx.is_isomorphic(nx.DiGraph(eval(a)),b):
            return a
    return m
def count_abnormal(l):
    one=0
    two=0
    three=0
    for i in l:
        if(i<4):
            three+=1
        if(i<3):
            two+=1
        if(i<2):
            one+=1
    return [one,two,three]
